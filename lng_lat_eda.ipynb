# %%
# 서울 아파트 csv 읽어오기
seoul_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/s_apt_final_please.csv")
seoul_df.tail()
# Out:
#       dong        apt               addr   area  completion  transaction_ym  \
# 78833  강일동  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지  59.72        2011          201711
# 78834  강일동  강일리버파크3단지  강일동 674 강일리버파크3단지  59.87        2009          201711
# 78835  강일동  강일리버파크3단지  강일동 674 강일리버파크3단지  84.74        2009          201711
# 78836  강일동  강일리버파크1단지  강일동 665 강일리버파크1단지  84.74        2009          201711
# 78837  강일동  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지  84.98        2011          201711
#
#        floor  price  price/pyeong   gu
# 78833      9  53000          2929  강동구
# 78834     12  53000          2921  강동구
# 78835      3  56500          2200  강동구
# 78836      9  55500          2161  강동구
# 78837      8  63750          2476  강동구

# %%
# 원진:동작구, 영웅:광진구, 진서:용산구

# %%
# 동작구
wj_df = seoul_df[seoul_df.gu == "동작구"]
wj_df
# Out:
#        dong    apt             addr    area  completion  transaction_ym  \
# 56034  신대방동    우성1     신대방동 565 우성1   66.69        1988          201711
# 56035  신대방동    우성1     신대방동 565 우성1  126.16        1988          201711
# 56036  신대방동    신동아  신대방동 360-17 신동아   48.18        1993          201711
# 56037  신대방동  성원상떼빌   신대방동 719 성원상떼빌  128.61        2006          201711
#
#        floor  price  price/pyeong   gu
# 56034     12  49700          2459  동작구
# 56035     11  73500          1923  동작구
# 56036     14  28500          1952  동작구
# 56037     10  68000          1745  동작구

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json

# naver api
client_id = '0d9uya4hfz';    # 할당받은 ID
client_pw = 'og6iJHV85sYHFeqzH9wvSN5kPDfK2bQWKghGmhhE';    # 할당받은 Secret

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='

# 주소 목록 파일
data = wj_df[1500:len(wj_df)+1]
data

# 네이버 지도 API 이용해서 위경도 찾기
geo_coordi = []     
for add in data['addr']:
    add_urlenc = parse.quote(add)  
    url = api_url + add_urlenc
    request = Request(url)
    request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
    request.add_header('X-NCP-APIGW-API-KEY', client_pw)
    try:
        response = urlopen(request)
    except HTTPError as e:
        print('HTTP Error!')
        latitude = None
        longitude = None
    else:
        rescode = response.getcode()
        if rescode == 200:
            response_body = response.read().decode('utf-8')
            response_body = json.loads(response_body)   # json
            if response_body['addresses'] == [] :
                print("'result' not exist!")
                latitude = None
                longitude = None
            else:
                latitude = response_body['addresses'][0]['y']
                longitude = response_body['addresses'][0]['x']
                print("Success!")
        else:
            print('Response error code : %d' % rescode)
            latitude = None
            longitude = None
    
    geo_coordi.append([latitude, longitude])


np_geo_coordi = np.array(geo_coordi)
pd_geo_coordi = pd.DataFrame({"gu": data['gu'].values,
                              "dong": data['dong'].values,
                              "apt": data['apt'].values,
                              "addr": data['addr'].values,
                              "area": data['area'].values,
                              "completion": data['completion'].values,
                              "transaction_ym": data['transaction_ym'].values,
                              "floor": data['floor'].values,
                              "price": data["price"].values,
                              "price/pyeong": data["price/pyeong"].values,
                              "latitude": np_geo_coordi[:, 0],
                              "longitude": np_geo_coordi[:, 1]})

pd_geo_coordi.to_csv('/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/dongjack2.csv',index="False")
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# ...

# %%
# 용산구 : 나눠서 위도 경도 구해준 후 합치기
dongjak1_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/dongjack1.csv")
dongjak2_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/dongjack2.csv")

# %%
dongjak_df = pd.concat([dongjak1_df, dongjak2_df], ignore_index=True)
dongjak_df.drop(columns=["Unnamed: 0"], axis=1, inplace=True)
dongjak_df.to_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/dongjack.csv")

# %%
# 광진구
yw_df = seoul_df[seoul_df.gu == "광진구"]
yw_df
# Out:
#      dong    apt              addr    area  completion  transaction_ym  floor  \
# 4448  중곡동  중곡2단지  중곡동 190-26 중곡2단지   55.87        1976          201701      1
# 4449  중곡동   에스케이      중곡동 292 에스케이   84.60        1999          201701     17
# 4450  중곡동  중곡1단지  중곡동 191-77 중곡1단지   48.46        1976          201701      5
# 4451  중곡동     성원        중곡동 681 성원   59.82        1998          201701     14
# 4452  중곡동   에스케이      중곡동 292 에스케이   84.60        1999          201701     15
# ...   ...    ...               ...     ...         ...             ...    ...
# 6505  군자동   일성파크       군자동 99 일성파크   84.96        1996          201710     19
# 6506  군자동  동양파라곤  군자동 360-20 동양파라곤  124.65        2008          201710      8
# 6507  군자동   일성파크       군자동 99 일성파크   59.96        1996          201711      6
# 6508  군자동   일성파크       군자동 99 일성파크   59.96        1996          201711      7
# 6509  군자동  동양파라곤  군자동 360-20 동양파라곤   84.98        2008          201711      5
#
#       price  price/pyeong   gu
# ...

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json

# naver api
client_id = '0d9uya4hfz';    # 할당받은 ID
client_pw = 'og6iJHV85sYHFeqzH9wvSN5kPDfK2bQWKghGmhhE';    # 할당받은 Secret

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='

# 주소 목록 파일
data = yw_df.copy()
data

# 네이버 지도 API 이용해서 위경도 찾기
geo_coordi = []     
for add in data['addr']:
    add_urlenc = parse.quote(add)  
    url = api_url + add_urlenc
    request = Request(url)
    request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
    request.add_header('X-NCP-APIGW-API-KEY', client_pw)
    try:
        response = urlopen(request)
    except HTTPError as e:
        print('HTTP Error!')
        latitude = None
        longitude = None
    else:
        rescode = response.getcode()
        if rescode == 200:
            response_body = response.read().decode('utf-8')
            response_body = json.loads(response_body)   # json
            if response_body['addresses'] == [] :
                print("'result' not exist!")
                latitude = None
                longitude = None
            else:
                latitude = response_body['addresses'][0]['y']
                longitude = response_body['addresses'][0]['x']
                print("Success!")
        else:
            print('Response error code : %d' % rescode)
            latitude = None
            longitude = None
    
    geo_coordi.append([latitude, longitude])


np_geo_coordi = np.array(geo_coordi)
pd_geo_coordi = pd.DataFrame({"gu": data['gu'].values,
                              "dong": data['dong'].values,
                              "apt": data['apt'].values,
                              "addr": data['addr'].values,
                              "area": data['area'].values,
                              "completion": data['completion'].values,
                              "transaction_ym": data['transaction_ym'].values,
                              "floor": data['floor'].values,
                              "price": data["price"].values,
                              "price/pyeong": data["price/pyeong"].values,
                              "latitude": np_geo_coordi[:, 0],
                              "longitude": np_geo_coordi[:, 1]})

pd_geo_coordi.to_csv('/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/gwangjin.csv',index="False")
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# ...

# %%
# 용산구
js_df = seoul_df[seoul_df.gu == "용산구"]
js_df
# Out:
#      dong      apt             addr    area  completion  transaction_ym  \
# 1406  후암동     후암미주   후암동 423-1 후암미주   62.28        1980          201701
# 1407  후암동  브라운스톤남산  후암동 458 브라운스톤남산  166.56        2004          201701
# 1408  후암동  브라운스톤남산  후암동 458 브라운스톤남산  166.56        2004          201702
# 1409  후암동   (41-1)  후암동 41-1 (41-1)   83.04        2012          201702
# 1410  후암동     후암맨션    후암동 1-20 후암맨션   72.13        1974          201703
# ...   ...      ...              ...     ...         ...             ...
# 2639  보광동     신동아1     보광동 448 신동아1   84.93        1992          201708
# 2640  보광동     신동아1     보광동 448 신동아1   84.93        1992          201708
# 2641  보광동  리버빌(삼성)  보광동 151 리버빌(삼성)   84.74        2000          201709
# 2642  보광동  리버빌(삼성)  보광동 151 리버빌(삼성)   84.74        2000          201710
# 2643  보광동     신동아1     보광동 448 신동아1   84.93        1992          201711
#
#       floor   price  price/pyeong   gu
# 1406      6   49000          2596  용산구
# ...

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json

# naver api
client_id = '0d9uya4hfz';    # 할당받은 ID
client_pw = 'og6iJHV85sYHFeqzH9wvSN5kPDfK2bQWKghGmhhE';    # 할당받은 Secret

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='

# 주소 목록 파일
data = js_df.copy()
data

# 네이버 지도 API 이용해서 위경도 찾기
geo_coordi = []     
for add in data['addr']:
    add_urlenc = parse.quote(add)  
    url = api_url + add_urlenc
    request = Request(url)
    request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
    request.add_header('X-NCP-APIGW-API-KEY', client_pw)
    try:
        response = urlopen(request)
    except HTTPError as e:
        print('HTTP Error!')
        latitude = None
        longitude = None
    else:
        rescode = response.getcode()
        if rescode == 200:
            response_body = response.read().decode('utf-8')
            response_body = json.loads(response_body)   # json
            if response_body['addresses'] == [] :
                print("'result' not exist!")
                latitude = None
                longitude = None
            else:
                latitude = response_body['addresses'][0]['y']
                longitude = response_body['addresses'][0]['x']
                print("Success!")
        else:
            print('Response error code : %d' % rescode)
            latitude = None
            longitude = None
    
    geo_coordi.append([latitude, longitude])


np_geo_coordi = np.array(geo_coordi)
pd_geo_coordi = pd.DataFrame({"gu": data['gu'].values,
                              "dong": data['dong'].values,
                              "apt": data['apt'].values,
                              "addr": data['addr'].values,
                              "area": data['area'].values,
                              "completion": data['completion'].values,
                              "transaction_ym": data['transaction_ym'].values,
                              "floor": data['floor'].values,
                              "price": data["price"].values,
                              "price/pyeong": data["price/pyeong"].values,
                              "latitude": np_geo_coordi[:, 0],
                              "longitude": np_geo_coordi[:, 1]})

pd_geo_coordi.to_csv('/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/yongsan.csv',index="False")
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# ...

# %%
# 지하철위경도
station_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/raw/전국지하철위경도정보.csv")
seoul_station_df = station_df[station_df["역지역"] == "수도권"]
seoul_station_df.tail(3)
# Out:
#      역이름  역지역       호선         위도          경도
# 725  삼양역  수도권  우이신설경전철  37.626912  127.018148
# 726  회기역  수도권      경의선  37.589778  127.058039
# 727  가좌역  수도권      경의선  37.568751  126.914811

# %%
seoul_station_df.to_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/seoul_sbway.csv")

# %%
# 공공도서관 위경도
library_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/2017 공공도서관.csv")
library_df = library_df[["시도","행정구","도서관명","주소"]]
library_df.tail(3)
# Out:
#      시도   행정구    도서관명                                      주소
# 190  제주  서귀포시   송악도서관  제주특별자치도 대정읍 동일하모로149번길 12 (대정읍. 송악도서관)
# 191  제주   제주시  한수풀도서관     제주특별자치도 제주시 한림읍 한림상로  240-11 한수풀도서관
# 192  제주  서귀포시   제남도서관  제주도 서귀포시 남원읍 남원체육관로   183. (남원읍 제남도서관)

# %%
seoul_lib_df = library_df[library_df["시도"] == "서울"]
seoul_lib_df.tail(3)
# Out:
#     시도  행정구           도서관명                         주소
# 18  서울  구로구  서울특별시교육청구로도서관     서울특별시 구로구 공원로 15 (구로동)
# 19  서울  동작구          동작도서관  서울특별시 동작구 장승배기로 94 (노량진동)
# 20  서울  용산구  서울특별시교육청남산도서관    서울특별시 용산구 소월로 109 (후암동)

# %%
seoul_lib_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      21 non-null     object
#  1   행정구     21 non-null     object
#  2   도서관명    21 non-null     object
#  3   주소      21 non-null     object
# dtypes: object(4)
# memory usage: 840.0+ bytes

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json



# naver api
client_id = '0d9uya4hfz';    # 본인이 할당받은 ID 입력
client_pw = 'og6iJHV85sYHFeqzH9wvSN5kPDfK2bQWKghGmhhE';    # 본인이 할당받은 Secret 입력

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='

# 주소 목록 파일
data = pd.read_csv('/Users/jinseo/Documents/dss/1_programming/Project/2017 서울도서관.csv')
data

# 네이버 지도 API 이용해서 위경도 찾기
geo_coordi = []     
for add in data['주소']:
    add_urlenc = parse.quote(add)  
    url = api_url + add_urlenc
    request = Request(url)
    request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
    request.add_header('X-NCP-APIGW-API-KEY', client_pw)
    try:
        response = urlopen(request)
    except HTTPError as e:
        print('HTTP Error!')
        latitude = None
        longitude = None
    else:
        rescode = response.getcode()
        if rescode == 200:
            response_body = response.read().decode('utf-8')
            response_body = json.loads(response_body)   # json
            if response_body['addresses'] == [] :
                print("'result' not exist!")
                latitude = None
                longitude = None
            else:
                latitude = response_body['addresses'][0]['y']
                longitude = response_body['addresses'][0]['x']
                print("Success!")
        else:
            print('Response error code : %d' % rescode)
            latitude = None
            longitude = None

    geo_coordi.append([latitude, longitude])

np_geo_coordi = np.array(geo_coordi)
pd_geo_coordi = pd.DataFrame({"시도": data['시도'].values,
                              "행정구": data['행정구'].values,
                              "도서관명": data['도서관명'].values,
                              "주소": data['주소'].values,
                              "위도": np_geo_coordi[:, 0],
                              "경도": np_geo_coordi[:, 1]})

pd_geo_coordi.to_csv('seoul_library.csv')
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!

# %%
library_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/2017_서울도서관.csv")
library_df.tail(3)
# Out:
#     Unnamed: 0  시도  행정구           도서관명                         주소         위도  \
# 18          18  서울  구로구  서울특별시교육청구로도서관     서울특별시 구로구 공원로 15 (구로동)  37.498663
# 19          19  서울  동작구          동작도서관  서울특별시 동작구 장승배기로 94 (노량진동)  37.505991
# 20          20  서울  용산구  서울특별시교육청남산도서관    서울특별시 용산구 소월로 109 (후암동)  37.552570
#
#             경도
# 18  126.891563
# 19  126.940167
# 20  126.982172

# %%
# 전통시장 위경도
market_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/전통시장.csv", encoding="utf-8")
market_df = market_df[["자치구","시장명", "주소"]]
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     377 non-null    object
#  1   시장명     377 non-null    object
#  2   주소      352 non-null    object
# dtypes: object(3)
# memory usage: 9.0+ KB

# %%
market_df = market_df.dropna(axis=0)
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 1 to 376
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     352 non-null    object
#  1   시장명     352 non-null    object
#  2   주소      352 non-null    object
# dtypes: object(3)
# memory usage: 11.0+ KB

# %%
market_df.tail(3)
# Out:
#      자치구           시장명                           주소
# 374  강동구         동서울시장  강동구 올림픽로80길 58\n(천호동 422-1)
# 375  강동구        고덕전통시장   강동구 고덕로83길 12\n(고덕동 210-5)
# 376  강동구  장신구 특화거리 상점가      강동구 성내로 83\n(성내동 545-6)

# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib import parse
from urllib.request import Request
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json


# naver api
client_id = '0d9uya4hfz';    # 본인이 할당받은 ID 입력
client_pw = 'og6iJHV85sYHFeqzH9wvSN5kPDfK2bQWKghGmhhE';    # 본인이 할당받은 Secret 입력

api_url = 'https://naveropenapi.apigw.ntruss.com/map-geocode/v2/geocode?query='


# 네이버 지도 API 이용해서 위경도 찾기
geo_coordi = []     
for add in market_df['주소']:
    add_urlenc = parse.quote(add)  
    url = api_url + add_urlenc
    request = Request(url)
    request.add_header('X-NCP-APIGW-API-KEY-ID', client_id)
    request.add_header('X-NCP-APIGW-API-KEY', client_pw)
    try:
        response = urlopen(request)
    except HTTPError as e:
        print('HTTP Error!')
        latitude = None
        longitude = None
    else:
        rescode = response.getcode()
        if rescode == 200:
            response_body = response.read().decode('utf-8')
            response_body = json.loads(response_body)   # json
            if response_body['addresses'] == [] :
                print("'result' not exist!")
                latitude = None
                longitude = None
            else:
                latitude = response_body['addresses'][0]['y']
                longitude = response_body['addresses'][0]['x']
                print("Success!")
        else:
            print('Response error code : %d' % rescode)
            latitude = None
            longitude = None

    geo_coordi.append([latitude, longitude])


np_geo_coordi = np.array(geo_coordi)
pd_geo_coordi = pd.DataFrame({"자치구": market_df['자치구'].values,
                              "시장명": market_df["시장명"].values,
                              "주소": market_df["주소"].values,
                              "위도": np_geo_coordi[:, 0],
                              "경도": np_geo_coordi[:, 1]})

pd_geo_coordi.to_csv('seoul_market.csv')
# Out:
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# 'result' not exist!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# 'result' not exist!
# Success!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# 'result' not exist!
# Success!
# 'result' not exist!
# Success!
# Success!
# Success!
# Success!
# 'result' not exist!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# Success!
# ...

# %%
# starbucks

# %%
starbucks_df = pd.read_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/raw/starbucks.csv")
starbucks_seoul_df = starbucks_df[starbucks_df["City"] == "Seoul"]
starbucks_seoul_df = starbucks_seoul_df[["Store Number", "Store Name", "Street Address", "Longitude", "Latitude"]]
starbucks_seoul_df.reset_index(drop=True, inplace=True)
starbucks_seoul_df.tail(3)
# Out:
#      Store Number         Store Name                  Street Address  \
# 240  49868-270947            Seogang     130 Changjeon-dong, Mapo-gu
# 241  16975-177885  Kkachisan-station  343-1, Hwagok-dong, Gangseo-gu
# 242  21625-213666      Gunja Station  478-5, Gunja-dong, Gwangjin-gu
#
#      Longitude  Latitude
# 240     126.93     37.55
# 241     126.85     37.53
# 242     127.44     37.33

# %%
starbucks_seoul_df.to_csv("/Users/jinseo/Documents/dss/1_programming/Project/EDA/datas/seoul_starbucks.csv")
