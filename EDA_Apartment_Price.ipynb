# %%
apart_df = pd.read_csv("/Users/jinseo/Downloads/project_EDA/apartment.csv")
apart_df.tail(3)
# Out:
#          transaction_id  apartment_id   city     dong jibun         apt  \
# 1216550         1234825          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
# 1216551         1234826          9586  부산광역시  정관읍 용수리  1364   정관신도시롯데캐슬
# 1216552         1234827          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
#
#                          addr_kr  exclusive_use_area  year_of_completion  \
# 1216550  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
# 1216551   정관읍 용수리 1364 정관신도시롯데캐슬            101.7400                2008
# 1216552  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
#
#          transaction_year_month transaction_date  floor  \
# 1216550                  201711            21~30      9
# 1216551                  201711            21~30      7
# 1216552                  201711            21~30     16
#
#          transaction_real_price
# 1216550                   29500
# 1216551                   26700
# 1216552                   28800

# %%
apart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216553 entries, 0 to 1216552
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# ...

# %%
apart_df.describe()
# Out:
#        transaction_id  apartment_id  exclusive_use_area  year_of_completion  \
# count    1.216553e+06  1.216553e+06        1.216553e+06        1.216553e+06
# mean     6.091530e+05  6.299685e+03        7.816549e+01        1.998297e+03
# std      3.526198e+05  3.581169e+03        2.915113e+01        8.941347e+00
# min      0.000000e+00  0.000000e+00        9.260000e+00        1.961000e+03
# 25%      3.041380e+05  3.345000e+03        5.976000e+01        1.993000e+03
# 50%      6.082760e+05  5.964000e+03        8.241000e+01        1.999000e+03
# 75%      9.124140e+05  9.436000e+03        8.497000e+01        2.005000e+03
# max      1.234827e+06  1.265800e+04        4.243200e+02        2.017000e+03
#
#        transaction_year_month         floor  transaction_real_price
# count            1.216553e+06  1.216553e+06            1.216553e+06
# mean             2.012984e+05  9.343291e+00            3.822769e+04
# std              2.905732e+02  6.606500e+00            3.104898e+04
# ...

# %%
apart_df.set_index("city", inplace=True)
apart_df.tail(3)
# Out:
#        transaction_id  apartment_id     dong jibun         apt  \
# city
# 부산광역시         1234825          9578  정관읍 용수리  1387  정관 동일스위트1차
# 부산광역시         1234826          9586  정관읍 용수리  1364   정관신도시롯데캐슬
# 부산광역시         1234827          9578  정관읍 용수리  1387  정관 동일스위트1차
#
#                        addr_kr  exclusive_use_area  year_of_completion  \
# city
# 부산광역시  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
# 부산광역시   정관읍 용수리 1364 정관신도시롯데캐슬            101.7400                2008
# 부산광역시  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
#
#        transaction_year_month transaction_date  floor  transaction_real_price
# city
# 부산광역시                  201711            21~30      9                   29500
# 부산광역시                  201711            21~30      7                   26700
# 부산광역시                  201711            21~30     16                   28800

# %%
apart_df.drop("부산광역시", axis = "index", inplace=True)
apart_df.tail(3)
# Out:
#        transaction_id  apartment_id dong jibun        apt            addr_kr  \
# city
# 서울특별시         1196847           682  강일동   674  강일리버파크3단지  강일동 674 강일리버파크3단지
# 서울특별시         1196848           680  강일동   665  강일리버파크1단지  강일동 665 강일리버파크1단지
# 서울특별시         1196849           996  강일동   717  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지
#
#        exclusive_use_area  year_of_completion  transaction_year_month  \
# city
# 서울특별시               84.74                2009                  201711
# 서울특별시               84.74                2009                  201711
# 서울특별시               84.98                2011                  201711
#
#       transaction_date  floor  transaction_real_price
# city
# 서울특별시            21~30      3                   56500
# 서울특별시            21~30      9                   55500
# 서울특별시            21~30      8                   63750

# %%
apart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 742285 entries, 서울특별시 to 서울특별시
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   transaction_id          742285 non-null  int64
#  1   apartment_id            742285 non-null  int64
#  2   dong                    742285 non-null  object
#  3   jibun                   742285 non-null  object
#  4   apt                     742285 non-null  object
#  5   addr_kr                 742285 non-null  object
#  6   exclusive_use_area      742285 non-null  float64
#  7   year_of_completion      742285 non-null  int64
#  8   transaction_year_month  742285 non-null  int64
#  9   transaction_date        742285 non-null  object
#  10  floor                   742285 non-null  int64
#  11  transaction_real_price  742285 non-null  int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 73.6+ MB

# %%
apart_df.drop(["transaction_id","apartment_id","jibun", "transaction_date"], axis=1, inplace=True)
apart_df.tail(3)
# Out:
#       dong        apt            addr_kr  exclusive_use_area  \
# city
# 서울특별시  강일동  강일리버파크3단지  강일동 674 강일리버파크3단지               84.74
# 서울특별시  강일동  강일리버파크1단지  강일동 665 강일리버파크1단지               84.74
# 서울특별시  강일동  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지               84.98
#
#        year_of_completion  transaction_year_month  floor  \
# city
# 서울특별시                2009                  201711      3
# 서울특별시                2009                  201711      9
# 서울특별시                2011                  201711      8
#
#        transaction_real_price
# city
# 서울특별시                   56500
# 서울특별시                   55500
# 서울특별시                   63750

# %%
apart_df = apart_df.rename({"addr_kr":"addr", "exclusive_use_area":"area", "transaction_year_month" : "transaction_date", "transaction_real_price":"price","price_per_m3":"price_per_area"}, axis="columns")
apart_df
# Out:
#       dong        apt               addr    area  year_of_completion  \
# city
# 서울특별시  신교동   신현(101동)  신교동 6-13 신현(101동)   84.82                2002
# 서울특별시  필운동     사직파크맨션     필운동 142 사직파크맨션   99.17                1973
# 서울특별시  필운동     두레엘리시안   필운동 174-1 두레엘리시안   84.74                2007
# 서울특별시  내수동      파크팰리스       내수동 95 파크팰리스  146.39                2003
# 서울특별시  내수동       킹스매너    내수동 110-15 킹스매너  194.43                2004
# ...    ...        ...                ...     ...                 ...
# 서울특별시  강일동  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지   59.72                2011
# 서울특별시  강일동  강일리버파크3단지  강일동 674 강일리버파크3단지   59.87                2009
# 서울특별시  강일동  강일리버파크3단지  강일동 674 강일리버파크3단지   84.74                2009
# 서울특별시  강일동  강일리버파크1단지  강일동 665 강일리버파크1단지   84.74                2009
# 서울특별시  강일동  고덕리엔파크2단지  강일동 717 고덕리엔파크2단지   84.98                2011
#
#        transaction_date  floor   price
# city
# 서울특별시            200801      2   37500
# 서울특별시            200801      6   20000
# ...

# %%
data_transdate = apart_df["transaction_date"] >= 201701
apart_df = apart_df[data_transdate]
apart_df
# Out:
#       dong              apt                   addr    area  \
# city
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   70.80
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  160.85
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  136.40
# ...    ...              ...                    ...     ...
# 서울특별시  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   59.72
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   59.87
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   84.74
# 서울특별시  강일동        강일리버파크1단지      강일동 665 강일리버파크1단지   84.74
# 서울특별시  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   84.98
#
#        year_of_completion  transaction_date  floor   price
# city
# 서울특별시                2008            201701      1   67000
# 서울특별시                2008            201701      8   89300
# 서울특별시                2008            201701     11  110000
# ...

# %%
apart_df.drop(["transaction_date"], axis=1, inplace=True)
apart_df
# Out:
# /Users/jinseo/opt/anaconda3/envs/fc14/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       dong              apt                   addr    area  \
# city
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   70.80
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  160.85
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  136.40
# ...    ...              ...                    ...     ...
# 서울특별시  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   59.72
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   59.87
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   84.74
# ...

# %%
apart_df["price_per_area"] = apart_df["price"] / apart_df["area"]
apart_df = apart_df.round(2)
apart_df
# Out:
#       dong              apt                   addr    area  \
# city
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   70.80
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  160.85
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 서울특별시  사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  136.40
# ...    ...              ...                    ...     ...
# 서울특별시  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   59.72
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   59.87
# 서울특별시  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   84.74
# 서울특별시  강일동        강일리버파크1단지      강일동 665 강일리버파크1단지   84.74
# 서울특별시  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   84.98
#
#        year_of_completion  floor   price  price_per_area
# city
# 서울특별시                2008      1   67000          946.33
# 서울특별시                2008      8   89300          944.87
# 서울특별시                2008     11  110000          683.87
# ...

# %%
apart_df = apart_df.reset_index(drop=True)
apart_df
# Out:
#       dong              apt                   addr    area  \
# 0      사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   70.80
# 1      사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 2      사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  160.85
# 3      사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)   94.51
# 4      사직동  광화문풍림스페이스본(9-0)  사직동 9 광화문풍림스페이스본(9-0)  136.40
# ...    ...              ...                    ...     ...
# 91359  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   59.72
# 91360  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   59.87
# 91361  강일동        강일리버파크3단지      강일동 674 강일리버파크3단지   84.74
# 91362  강일동        강일리버파크1단지      강일동 665 강일리버파크1단지   84.74
# 91363  강일동        고덕리엔파크2단지      강일동 717 고덕리엔파크2단지   84.98
#
#        year_of_completion  floor   price  price_per_area
# 0                    2008      1   67000          946.33
# 1                    2008      8   89300          944.87
# 2                    2008     11  110000          683.87
# ...
